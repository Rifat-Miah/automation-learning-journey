# %%
# %pip install -U google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: google-genai in c:\users\asus\appdata\roaming\python\python313\site-packages (2.18.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\asus\appdata\roaming\python\python313\site-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in c:\users\asus\appdata\roaming\python\python313\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.56.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\programdata\anaconda3\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in c:\users\asus\appdata\roaming\python\python313\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\programdata\anaconda3\lib\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\programdata\anaconda3\lib\site-packages (from google-genai) (9.0.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\asus\appdata\roaming\python\python313\site-packages (from google-genai) (16.1.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\asus\appdata\roaming\python\python313\site-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from google-genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (44.0.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\asus\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asus\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (1.17.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.8)

# %%
# %pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
my_api_key = os.getenv("GEMINI_API_KEY")

from google import genai

client = genai.Client(
    api_key=my_api_key
)

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Describe the natural beauty of Bangladesh in 5 sentences."
)

print(response.text)
# Out:
# Known as the land of rivers, Bangladesh is a tropical paradise wrapped in endless stretches of emerald-green vegetation and shimmering waterways. To the south lies Cox’s Bazar, home to the world’s longest unbroken natural sandy beach, where golden shores meet the gentle waves of the Bay of Bengal. Deep within its borders, the majestic Sundarbans—the world's largest mangrove forest—harbors a rich ecosystem and the iconic Royal Bengal Tiger. Moving northeast, the gentle rolling hills of Sylhet are carpeted with sprawling, lush tea gardens that offer serene and misty views. Enhanced by the unique charm of six distinct seasons, the entire countryside blossoms into a breathtaking tapestry of vibrant water lilies and tranquil rural beauty, especially during the refreshing monsoons.

# %%
from google import genai

client = genai.Client(
    api_key=my_api_key
)

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Describe the natural beauty of Bangladesh in 5 sentences."
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-3.6-flash",
#       3     contents="Describe the natural beauty of Bangladesh in 5 sentences."
#       4 )
#       6 print(response.text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:6600, in Models.generate_content(self, model, contents, config)
#    6594   parsed_config_to_call = _extra_utils.get_usage_header(
#    6595       parsed_config_to_call,
#    6596       types.GenerateContentConfig,
#    6597       'afc',
#    6598   )
#    6599 i += 1
# -> 6600 response = self._generate_content(
#    6601     model=model, contents=contents, config=parsed_config_to_call
#    6602 )
#    6604 if not function_map:
#    6605   break
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:5028, in Models._generate_content(self, model, contents, config)
#    5025 request_dict = _common.convert_to_dict(request_dict)
#    5026 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5028 response = self._api_client.request(
#    5029     'post', path, request_dict, http_options
#    5030 )
#    5032 if config is not None and getattr(
#    5033     config, 'should_return_http_response', None
#    5034 ):
#    5035   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1747, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1737 def request(
#    1738     self,
#    1739     http_method: str,
#    (...)
#    1742     http_options: Optional[HttpOptionsOrDict] = None,
#    1743 ) -> SdkHttpResponse:
#    1744   http_request = self._build_request(
#    1745       http_method, path, request_dict, http_options
#    1746   )
# -> 1747   response = self._request(http_request, http_options, stream=False)
#    1748   response_body = (
#    1749       response.response_stream[0] if response.response_stream else ''
#    1750   )
#    1751   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1534, in BaseApiClient._request(self, http_request, http_options, stream)
#    1531     retry = tenacity.Retrying(**retry_kwargs)
#    1532     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1534 return self._retry(self._request_once, http_request, stream)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tenacity\__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tenacity\__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1511, in BaseApiClient._request_once(self, http_request, stream)
#    1503   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1504       method=http_request.method,
#    1505       url=http_request.url,
#    (...)
#    1508       timeout=http_request.timeout,
#    1509   )
#    1510   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr, arg-type]
# -> 1511 errors.APIError.raise_for_response(response)
#    1512 return HttpResponse(
#    1513     response.headers, response if stream else [response.text]
#    1514 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\errors.py:173, in APIError.raise_for_response(cls, response)
#     170 else:
#     171   response_json = response.body_segments[0].get('error', {})
# --> 173 cls.raise_error(response.status_code, response_json, response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\errors.py:204, in APIError.raise_error(cls, status_code, response_json, response)
#     202   raise ClientError(status_code, response_json, response)
#     203 elif 500 <= status_code < 600:
# --> 204   raise ServerError(status_code, response_json, response)
#     205 else:
#     206   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
